# %%
import numpy as np
import pandas as pd
import os
import plotly.graph_objects as go

# -------------------------------------------------
# Custom Plotly Template (provided by you)
# -------------------------------------------------
fig_template = go.layout.Template()
fig_template.layout = {
    'template': 'simple_white+presentation',
    'autosize': False,
    'width': 800,
    'height': 600,
    'xaxis': {
        'ticks': 'inside',
        'mirror': 'ticks',
        'linewidth': 2.5,
        'tickwidth': 2.5,
        'ticklen': 4,
        'showline': True,
        'showgrid': False,
        'zerolinecolor': 'white',
    },
    'yaxis': {
        'ticks': 'inside',
        'mirror': 'ticks',
        'linewidth': 2.5,
        'tickwidth': 2.5,
        'ticklen': 4,
        'showline': True,
        'showgrid': False,
        'zerolinecolor': 'white',
    },
    'font': {
        'family': 'mathjax',
        'size': 30,
    }
}

# -------------------------------------------------
# 1. Load data
# -------------------------------------------------
def load_data(file_path):
    data = pd.read_excel(file_path)
    return data["A"].values


# -------------------------------------------------
# 2. Unweighted mean and error
# -------------------------------------------------
def compute_unweighted_mean(values):
    N = len(values)
    mean = np.mean(values)
    std = np.std(values, ddof=1)
    error = std / np.sqrt(N)
    return mean, error


# -------------------------------------------------
# 3. Deterministic k'
# -------------------------------------------------
def compute_k_direct(a_mean, beta, k_J, k_kT):
    return k_J / (k_kT * beta**3 * a_mean**3)


# -------------------------------------------------
# 4. Monte Carlo propagation
# -------------------------------------------------
def monte_carlo_k(a_mean, a_error, beta, k_J, k_kT, N=300_000):

    a_samples = np.random.normal(a_mean, a_error, N)
    a_samples = a_samples[a_samples > 0]

    while len(a_samples) < N:
        extra = np.random.normal(a_mean, a_error, N - len(a_samples))
        extra = extra[extra > 0]
        a_samples = np.concatenate([a_samples, extra])

    a_samples = a_samples[:N]

    C = k_J / (k_kT * beta**3)
    k_samples = C / (a_samples**3)

    return k_samples


# -------------------------------------------------
# 5. Extract statistics
# -------------------------------------------------
def summarize_distribution(samples):
    median = np.median(samples)
    lower = np.percentile(samples, 16)
    upper = np.percentile(samples, 84)
    return median, lower, upper


# -------------------------------------------------
# 6. Process one dataset
# -------------------------------------------------
def process_dataset(file_path, beta, k_J, k_kT):

    name = os.path.basename(file_path).replace(".xlsx", "")
    print(f"\n==============================")
    print(f"Dataset: {name}")
    print(f"==============================")

    a_values = load_data(file_path)
    a_mean, a_error = compute_unweighted_mean(a_values)

    print(f"a = {a_mean:.3e} ± {a_error:.3e}")

    k_direct = compute_k_direct(a_mean, beta, k_J, k_kT)
    print(f"Deterministic k' = {k_direct:.3e}")

    k_samples = monte_carlo_k(a_mean, a_error, beta, k_J, k_kT)
    median, lower, upper = summarize_distribution(k_samples)

    print("Monte Carlo result:")
    print(f"k' = {median:.3e} +{upper - median:.3e} -{median - lower:.3e}")

    return name, k_samples


# -------------------------------------------------
# 7. Main
# -------------------------------------------------
def main():

    beta = 9.93e10
    k_J = 4.56e-8
    k_kT = 4.11e-21

    file_paths = [
        r"D:\Atanu\Narendran_GUV\Narendran_GUV\control.xlsx",
        r"D:\Atanu\Narendran_GUV\Narendran_GUV\10_fibrils.xlsx",
        r"D:\Atanu\Narendran_GUV\Narendran_GUV\30_fibrils.xlsx",
        r"D:\Atanu\Narendran_GUV\Narendran_GUV\10_monomar.xlsx",
        r"D:\Atanu\Narendran_GUV\Narendran_GUV\30_monomar.xlsx",
        
    ]

    all_samples = {}
    results = []

    # --- Compute results ---
    for path in file_paths:
        name, samples = process_dataset(path, beta, k_J, k_kT)
        all_samples[name] = samples

        # store summary for plotting
        median, lower, upper = summarize_distribution(samples)
        results.append((name, median, lower, upper))

    # --- Plot bar chart with asymmetric error bars ---
    names = [r[0] for r in results]
    medians = [r[1] for r in results]
    err_low = [r[1] - r[2] for r in results]
    err_high = [r[3] - r[1] for r in results]

    colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd']
    
    fig = go.Figure()
    fig.add_trace(
        go.Bar(
            x=names,
            y=medians,
            error_y=dict(
                type='data',
                symmetric=False,
                array=err_high,
                arrayminus=err_low,
                thickness=2.5,
                width=6
            ),
            marker=dict(color=colors)
        )
    )

    fig.update_layout(
        template=fig_template,
        # xaxis_title="Dataset",
        width = 800,
        height = 650,
        yaxis_title="Bending Rigidity (k<sub>B</sub>T)",
        margin=dict(l=110, r=50, t=70, b=80),
    )

    fig.show()


# -------------------------------------------------
# Run
# -------------------------------------------------
if __name__ == "__main__":
    main()
# Out:
# ==============================
# Dataset: control
# ==============================
# a = 7.177e-08 ± 1.272e-08
# Deterministic k' = 3.065e+01
# Monte Carlo result:
# k' = 3.067e+01 +2.421e+01 -1.176e+01
#
# ==============================
# Dataset: 10_fibrils
# ==============================
# a = 6.492e-08 ± 2.294e-08
# Deterministic k' = 4.141e+01
# Monte Carlo result:
# k' = 4.112e+01 +1.085e+02 -2.433e+01
#
# ==============================
# Dataset: 30_fibrils
# ==============================
# a = 8.820e-08 ± 1.613e-08
# Deterministic k' = 1.651e+01
# Monte Carlo result:
# k' = 1.649e+01 +1.353e+01 -6.505e+00
#
# ==============================
# Dataset: 10_monomar
# ==============================
# a = 9.165e-08 ± 2.047e-08
# Deterministic k' = 1.472e+01
# Monte Carlo result:
# k' = 1.470e+01 +1.653e+01 -6.650e+00
#
# ==============================
# Dataset: 30_monomar
# ==============================
# a = 1.149e-07 ± 8.647e-08
# Deterministic k' = 7.473e+00
# Monte Carlo result:
# k' = 5.805e+00 +7.000e+01 -4.515e+00

# %%
import numpy as np
import pandas as pd
import os
import plotly.graph_objects as go

# -------------------------------------------------
# Custom Plotly Template (provided by you)
# -------------------------------------------------
fig_template = go.layout.Template()
fig_template.layout = {
    'template': 'simple_white+presentation',
    'autosize': False,
    'width': 800,
    'height': 600,
    'xaxis': {
        'ticks': 'inside',
        'mirror': 'ticks',
        'linewidth': 2.5,
        'tickwidth': 2.5,
        'ticklen': 4,
        'showline': True,
        'showgrid': False,
        'zerolinecolor': 'white',
    },
    'yaxis': {
        'ticks': 'inside',
        'mirror': 'ticks',
        'linewidth': 2.5,
        'tickwidth': 2.5,
        'ticklen': 4,
        'showline': True,
        'showgrid': False,
        'zerolinecolor': 'white',
    },
    'font': {
        'family': 'mathjax',
        'size': 30,
    }
}

# -------------------------------------------------
# 1. Load data
# -------------------------------------------------
def load_data(file_path):
    data = pd.read_excel(file_path)
    return data["A"].values

# -------------------------------------------------
# 2. Unweighted mean and error
# -------------------------------------------------
def compute_unweighted_mean(values):
    N = len(values)
    mean = np.mean(values)
    std = np.std(values, ddof=1)
    error = std / np.sqrt(N)
    return mean, error

# -------------------------------------------------
# 3. Deterministic k'
# -------------------------------------------------
def compute_k_direct(a_mean, beta, k_J, k_kT):
    return k_J / (k_kT * beta**3 * a_mean**3)

# -------------------------------------------------
# 4. Linear error propagation for k'
# -------------------------------------------------
def linear_error_k(a_mean, a_error, beta, k_J, k_kT):
    C = k_J / (k_kT * beta**3)
    k_mean = C / (a_mean**3)

    # linear error propagation:
    k_error = 3 * C * a_error / (a_mean**4)
    return k_mean, k_error

# -------------------------------------------------
# 5. Process one dataset
# -------------------------------------------------
def process_dataset(file_path, beta, k_J, k_kT):

    name = os.path.basename(file_path).replace(".xlsx", "")
    print(f"\n==============================")
    print(f"Dataset: {name}")
    print(f"==============================")

    a_values = load_data(file_path)
    a_mean, a_error = compute_unweighted_mean(a_values)

    print(f"a = {a_mean:.3e} ± {a_error:.3e}")

    k_direct = compute_k_direct(a_mean, beta, k_J, k_kT)
    print(f"Deterministic k' = {k_direct:.3e}")

    k_mean, k_error = linear_error_k(a_mean, a_error, beta, k_J, k_kT)

    # prevent lower bound below zero
    k_lower = max(0, k_mean - k_error)
    k_upper = k_mean + k_error

    print("Linear propagation result:")
    print(f"k' = {k_mean:.3e} +{k_upper-k_mean:.3e} -{k_mean-k_lower:.3e}")

    return name, k_mean, k_lower, k_upper

# -------------------------------------------------
# 6. Main
# -------------------------------------------------
def main():

    beta = 9.93e10
    k_J = 4.56e-8
    k_kT = 4.11e-21

    file_paths = [
        r"D:\Atanu\Narendran_GUV\Narendran_GUV\control.xlsx",
        r"D:\Atanu\Narendran_GUV\Narendran_GUV\10_fibrils.xlsx",
        r"D:\Atanu\Narendran_GUV\Narendran_GUV\30_fibrils.xlsx",
        r"D:\Atanu\Narendran_GUV\Narendran_GUV\10_monomar.xlsx",
        r"D:\Atanu\Narendran_GUV\Narendran_GUV\30_monomar.xlsx",
    ]

    results = []

    for path in file_paths:
        name, k_mean, k_lower, k_upper = process_dataset(path, beta, k_J, k_kT)
        results.append((name, k_mean, k_lower, k_upper))

    # --- Plot bar chart with symmetric error bars ---
    names = [r[0] for r in results]
    means = [r[1] for r in results]
    err_low = [r[1] - r[2] for r in results]
    err_high = [r[3] - r[1] for r in results]

    colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd']

    fig = go.Figure()
    fig.add_trace(
        go.Bar(
            x=names,
            y=means,
            error_y=dict(
                type='data',
                symmetric=False,
                array=err_high,
                arrayminus=err_low,
                thickness=2.5,
                width=6
            ),
            marker=dict(color=colors)
        )
    )

    fig.update_layout(
        template=fig_template,
        width=800,
        height=650,
        yaxis_title="Bending Rigidity (k<sub>B</sub>T)",
        margin=dict(l=110, r=50, t=70, b=80),
    )

    fig.show()

# -------------------------------------------------
# Run
# -------------------------------------------------
if __name__ == "__main__":
    main()
# Out:
# ==============================
# Dataset: control
# ==============================
# a = 7.177e-08 ± 1.272e-08
# Deterministic k' = 3.065e+01
# Linear propagation result:
# k' = 3.065e+01 +1.630e+01 -1.630e+01
#
# ==============================
# Dataset: 10_fibrils
# ==============================
# a = 6.492e-08 ± 2.294e-08
# Deterministic k' = 4.141e+01
# Linear propagation result:
# k' = 4.141e+01 +4.388e+01 -4.141e+01
#
# ==============================
# Dataset: 30_fibrils
# ==============================
# a = 8.820e-08 ± 1.613e-08
# Deterministic k' = 1.651e+01
# Linear propagation result:
# k' = 1.651e+01 +9.062e+00 -9.062e+00
#
# ==============================
# Dataset: 10_monomar
# ==============================
# a = 9.165e-08 ± 2.047e-08
# Deterministic k' = 1.472e+01
# Linear propagation result:
# k' = 1.472e+01 +9.862e+00 -9.862e+00
#
# ==============================
# Dataset: 30_monomar
# ==============================
# a = 1.149e-07 ± 8.647e-08
# Deterministic k' = 7.473e+00
# Linear propagation result:
# k' = 7.473e+00 +1.688e+01 -7.473e+00

# %%
import numpy as np
import pandas as pd
import os
import plotly.graph_objects as go

# -------------------------------------------------
# Custom Plotly Template (provided by you)
# -------------------------------------------------
fig_template = go.layout.Template()
fig_template.layout = {
    'template': 'simple_white+presentation',
    'autosize': False,
    'width': 800,
    'height': 600,
    'xaxis': {
        'ticks': 'inside',
        'mirror': 'ticks',
        'linewidth': 2.5,
        'tickwidth': 2.5,
        'ticklen': 4,
        'showline': True,
        'showgrid': False,
        'zerolinecolor': 'white',
    },
    'yaxis': {
        'ticks': 'inside',
        'mirror': 'ticks',
        'linewidth': 2.5,
        'tickwidth': 2.5,
        'ticklen': 4,
        'showline': True,
        'showgrid': False,
        'zerolinecolor': 'white',
    },
    'font': {
        'family': 'mathjax',
        'size': 30,
    }
}

# -------------------------------------------------
# 1. Load data
# -------------------------------------------------
def load_data(file_path):
    data = pd.read_excel(file_path)
    return data["A"].values


# -------------------------------------------------
# 2. Compute k' values for each A
# -------------------------------------------------
def compute_k_values(a_values, beta, k_J, k_kT):
    C = k_J / (k_kT * beta**3)
    return C / (a_values**3)


# -------------------------------------------------
# 3. Compute mean and SEM of k'
# -------------------------------------------------
def compute_mean_sem(values):
    mean = np.mean(values)
    sem = np.std(values, ddof=1) / np.sqrt(len(values))
    return mean, sem


# -------------------------------------------------
# 4. Process one dataset
# -------------------------------------------------
def process_dataset(file_path, beta, k_J, k_kT):

    name = os.path.basename(file_path).replace(".xlsx", "")
    print(f"\n==============================")
    print(f"Dataset: {name}")
    print(f"==============================")

    a_values = load_data(file_path)
    
    # Compute k' for each A
    k_values = compute_k_values(a_values, beta, k_J, k_kT)

    # Mean and error of k'
    k_mean, k_sem = compute_mean_sem(k_values)

    print(f"Mean k' = {k_mean:.3e} ± {k_sem:.3e}")

    return name, k_values, k_mean, k_sem


# -------------------------------------------------
# 5. Main
# -------------------------------------------------
def main():

    beta = 9.93e10
    k_J = 4.56e-8
    k_kT = 4.11e-21

    file_paths = [
        r"D:\Atanu\Narendran_GUV\Narendran_GUV\control.xlsx",
        r"D:\Atanu\Narendran_GUV\Narendran_GUV\10_fibrils.xlsx",
        r"D:\Atanu\Narendran_GUV\Narendran_GUV\30_fibrils.xlsx",
        r"D:\Atanu\Narendran_GUV\Narendran_GUV\10_monomar.xlsx",
        r"D:\Atanu\Narendran_GUV\Narendran_GUV\30_monomar.xlsx",
    ]

    results = []

    for path in file_paths:
        name, k_values, k_mean, k_sem = process_dataset(path, beta, k_J, k_kT)
        results.append((name, k_mean, k_sem, k_values))

    # Plot bar chart
    names = [r[0] for r in results]
    means = [r[1] for r in results]
    errors = [r[2] for r in results]

    fig = go.Figure()
    fig.add_trace(
        go.Bar(
            x=names,
            y=means,
            error_y=dict(
                type='data',
                symmetric=True,
                array=errors,
                thickness=2.5,
                width=6
            ),
            marker=dict(color='steelblue')
        )
    )

    fig.update_layout(
        template=fig_template,
        yaxis_title="Bending Rigidity (k<sub>B</sub>T)",
        margin=dict(l=110, r=50, t=70, b=80),
    )

    fig.show()

if __name__ == "__main__":
    main()
# Out:
# ==============================
# Dataset: control
# ==============================
# Mean k' = 5.048e+01 ± 3.168e+01
#
# ==============================
# Dataset: 10_fibrils
# ==============================
# Mean k' = 3.303e+02 ± 3.085e+02
#
# ==============================
# Dataset: 30_fibrils
# ==============================
# Mean k' = 2.815e+01 ± 1.814e+01
#
# ==============================
# Dataset: 10_monomar
# ==============================
# Mean k' = 3.357e+01 ± 2.536e+01
#
# ==============================
# Dataset: 30_monomar
# ==============================
# Mean k' = 3.345e+02 ± 1.726e+02
